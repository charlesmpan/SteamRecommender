# %% [markdown]
# # This notebook is a test for streamlit

# %%
# pip installations

# conda install -c conda-forge scikit-surprise
# !pip install matplotlib (If you haven't done before)
# !pip install seaborn (If you haven't done before)
# !pip install IPython
# !pip install Streamlit
# !pip install ast

# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time
import re
import ast

# third-party imports
import numpy as np
import pandas as pd
import streamlit as st
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MultiLabelBinarizer
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit
from IPython.display import display
from IPython.display import Image
from IPython.core.display import display, HTML
from ast import literal_eval
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_2668\2738183826.py:23: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
steam = pd.read_csv('./data/SteamFinal.csv')
steam
# Out:
#          AppID                                               Name  \
# 0           10                                     Counter-Strike
# 1           20                              Team Fortress Classic
# 2           30                                      Day of Defeat
# 3           40                                 Deathmatch Classic
# 4           50                          Half-Life: Opposing Force
# ...        ...                                                ...
# 15787  2095450                                       Tiny Tactics
# 15788  2097720  Black Market of Bulletphilia  ~ 100th Black Ma...
# 15789  2103640                                 Axis Football 2023
# 15790  2111630                            JR EAST Train Simulator
# 15791  2114370                            Takoyaki Party Survival
#
#                                              Description  \
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 15787  Tiny Tactics is a Tower Defense game with a <i...
# 15788  東方Project第18.5弾<br>上海アリス幻樂団による弾幕シューティング！<br><b...
# 15789  <strong>Axis Football 2023 features completely...
# 15790  Ongakukan and JR East have teamed up to bring ...
# 15791  <strong>The ninth of low-price series of Kimid...
#
#                             Publisher               Developer  Release_Date  \
# 0                           ['Valve']               ['Valve']   Nov 1, 2000
# 1                           ['Valve']               ['Valve']   Apr 1, 1999
# 2                           ['Valve']               ['Valve']   May 1, 2003
# 3                           ['Valve']               ['Valve']   Jun 1, 2001
# 4                           ['Valve']    ['Gearbox Software']   Nov 1, 1999
# ...                               ...                     ...           ...
# 15787           ['Tiny Forge Gaming']   ['Tiny Forge Gaming']   Aug 5, 2022
# 15788        ['Mediascape Co., Ltd.']            ['上海アリス幻樂団']  Aug 14, 2022
# 15789                  ['Axis Games']          ['Axis Games']   Sep 7, 2022
# 15790  ['East Japan Railway Company']  ['ONGAKUKAN Co.,Ltd.']  Sep 19, 2022
# 15791               ['KIMIDORI SOFT']       ['KIMIDORI SOFT']  Aug 26, 2022
#
#        Price                                         Categories  \
# 0       9.99  ['Multiplayer', 'PvP', 'Shared/SplitScreenPvP'...
# 1       4.99  ['Multiplayer', 'PvP', 'Shared/SplitScreenPvP'...
# 2       4.99                                ['Multiplayer', '']
# 3       4.99  ['Multiplayer', 'PvP', 'Shared/SplitScreenPvP'...
# 4       4.99  ['Singleplayer', 'Multiplayer', 'RemotePlayTog...
# ...      ...                                                ...
# 15787   9.99                               ['Singleplayer', '']
# 15788  14.99                               ['Singleplayer', '']
# 15789  19.99  ['Singleplayer', 'Multiplayer', 'PvP', 'Shared...
# 15790   9.99                                   ['Singleplayer']
# 15791   2.99        ['Singleplayer', 'Multiplayer', 'Coop', '']
#
#                                               Genres  \
# 0                                         ['Action']
# 1                                         ['Action']
# 2                                         ['Action']
# 3                                         ['Action']
# 4                                         ['Action']
# ...                                              ...
# 15787                          ['Indie', 'Strategy']
# 15788                            ['Action', 'Indie']
# 15789  ['Indie', 'Simulation', 'Sports', 'Strategy']
# 15790                  ['Simulation', 'EarlyAccess']
# 15791              ['Casual', 'Indie', 'Simulation']
#
#                                                     Tags  Total_Reviews  \
# 0      ['Action', 'FPS', 'Multiplayer', 'Shooter', 'C...         205327
# 1      ['Action', 'FPS', 'Multiplayer', 'Classic', 'H...           6716
# 2      ['FPS', 'WorldWarII', 'Multiplayer', 'Shooter'...           5786
# 3      ['Action', 'FPS', 'Classic', 'Multiplayer', 'S...           2387
# 4      ['FPS', 'Action', 'Classic', 'Sci-fi', 'Single...          15489
# ...                                                  ...            ...
# 15787  ['Strategy', 'TowerDefense', 'D', 'Top-Down', ...            391
# 15788  ['ShootEmUp', 'Shooter', 'FemaleProtagonist', ...            379
# 15789  ['Sports', 'Simulation', 'Strategy', 'Football...            115
# 15790  ['Simulation', 'Trains', 'Driving', 'Transport...            272
# 15791  ['TimeManagement', 'Collectathon', 'Survival',...            131
#
#        Sentiment PriceRange SentimentRange        ReviewRange  \
# 0       0.974860    ['Mid']     ['Raving']  ['ReallyPopular']
# 1       0.861823  ['Cheap']       ['Good']  ['ReallyPopular']
# 2       0.902523  ['Cheap']     ['Raving']  ['ReallyPopular']
# 3       0.818182  ['Cheap']        ['Mid']  ['ReallyPopular']
# 4       0.951837  ['Cheap']     ['Raving']  ['ReallyPopular']
# ...          ...        ...            ...                ...
# 15787   0.859335    ['Mid']       ['Good']            ['Mid']
# 15788   0.831135   ['High']       ['Good']            ['Mid']
# 15789   0.895652   ['High']       ['Good']            ['Low']
# 15790   0.735294    ['Mid']        ['Mid']            ['Mid']
# 15791   0.938931  ['Cheap']     ['Raving']            ['Low']
#
#                                                   Labels
# 0      ['Valve', 'Valve', 'Action', 'Multiplayer', 'P...
# 1      ['Valve', 'Valve', 'Action', 'Multiplayer', 'P...
# 2      ['Valve', 'Valve', 'Action', 'Multiplayer', ''...
# 3      ['Valve', 'Valve', 'Action', 'Multiplayer', 'P...
# 4      ['Gearbox Software', 'Valve', 'Action', 'Singl...
# ...                                                  ...
# 15787  ['Tiny Forge Gaming', 'Tiny Forge Gaming', 'In...
# 15788  ['上海アリス幻樂団', 'Mediascape Co., Ltd.', 'Action',...
# 15789  ['Axis Games', 'Axis Games', 'Indie', 'Simulat...
# 15790  ['ONGAKUKAN Co.,Ltd.', 'East Japan Railway Com...
# 15791  ['KIMIDORI SOFT', 'KIMIDORI SOFT', 'Casual', '...
#
# [15792 rows x 16 columns]

# %%
steam['ReviewRange'] = steam['ReviewRange'].apply(lambda x: ast.literal_eval(x))
steam['SentimentRange'] = steam['SentimentRange'].apply(lambda x: ast.literal_eval(x))
steam['Labels'] = steam['Labels'].apply(lambda x: ast.literal_eval(x))
steam['Tags'] = steam['Tags'].apply(lambda x: ast.literal_eval(x))
steam['Categories'] = steam['Categories'].apply(lambda x: ast.literal_eval(x))
steam['Genres'] = steam['Genres'].apply(lambda x: ast.literal_eval(x))
steam = steam.set_index('AppID')

#Turning these categories into lists with ast.literal_eval

# %%
steam
# Out:
#                                                       Name  \
# AppID
# 10                                          Counter-Strike
# 20                                   Team Fortress Classic
# 30                                           Day of Defeat
# 40                                      Deathmatch Classic
# 50                               Half-Life: Opposing Force
# ...                                                    ...
# 2095450                                       Tiny Tactics
# 2097720  Black Market of Bulletphilia  ~ 100th Black Ma...
# 2103640                                 Axis Football 2023
# 2111630                            JR EAST Train Simulator
# 2114370                            Takoyaki Party Survival
#
#                                                Description  \
# AppID
# 10       Play the world's number 1 online action game. ...
# 20       One of the most popular online action games of...
# 30       Enlist in an intense brand of Axis vs. Allied ...
# 40       Enjoy fast-paced multiplayer gaming with Death...
# 50       Return to the Black Mesa Research Facility as ...
# ...                                                    ...
# 2095450  Tiny Tactics is a Tower Defense game with a <i...
# 2097720  東方Project第18.5弾<br>上海アリス幻樂団による弾幕シューティング！<br><b...
# 2103640  <strong>Axis Football 2023 features completely...
# 2111630  Ongakukan and JR East have teamed up to bring ...
# 2114370  <strong>The ninth of low-price series of Kimid...
#
#                               Publisher               Developer  Release_Date  \
# AppID
# 10                            ['Valve']               ['Valve']   Nov 1, 2000
# 20                            ['Valve']               ['Valve']   Apr 1, 1999
# 30                            ['Valve']               ['Valve']   May 1, 2003
# 40                            ['Valve']               ['Valve']   Jun 1, 2001
# 50                            ['Valve']    ['Gearbox Software']   Nov 1, 1999
# ...                                 ...                     ...           ...
# 2095450           ['Tiny Forge Gaming']   ['Tiny Forge Gaming']   Aug 5, 2022
# 2097720        ['Mediascape Co., Ltd.']            ['上海アリス幻樂団']  Aug 14, 2022
# 2103640                  ['Axis Games']          ['Axis Games']   Sep 7, 2022
# 2111630  ['East Japan Railway Company']  ['ONGAKUKAN Co.,Ltd.']  Sep 19, 2022
# 2114370               ['KIMIDORI SOFT']       ['KIMIDORI SOFT']  Aug 26, 2022
#
#          Price                                         Categories  \
# AppID
# 10        9.99        [Multiplayer, PvP, Shared/SplitScreenPvP, ]
# 20        4.99  [Multiplayer, PvP, Shared/SplitScreenPvP, Remo...
# 30        4.99                                    [Multiplayer, ]
# 40        4.99  [Multiplayer, PvP, Shared/SplitScreenPvP, Remo...
# 50        4.99    [Singleplayer, Multiplayer, RemotePlayTogether]
# ...        ...                                                ...
# 2095450   9.99                                   [Singleplayer, ]
# 2097720  14.99                                   [Singleplayer, ]
# 2103640  19.99  [Singleplayer, Multiplayer, PvP, Shared/SplitS...
# 2111630   9.99                                     [Singleplayer]
# 2114370   2.99                [Singleplayer, Multiplayer, Coop, ]
#
#                                         Genres  \
# AppID
# 10                                    [Action]
# 20                                    [Action]
# 30                                    [Action]
# 40                                    [Action]
# 50                                    [Action]
# ...                                        ...
# 2095450                      [Indie, Strategy]
# 2097720                        [Action, Indie]
# 2103640  [Indie, Simulation, Sports, Strategy]
# 2111630              [Simulation, EarlyAccess]
# 2114370            [Casual, Indie, Simulation]
#
#                                                       Tags  Total_Reviews  \
# AppID
# 10       [Action, FPS, Multiplayer, Shooter, Classic, T...         205327
# 20       [Action, FPS, Multiplayer, Classic, HeroShoote...           6716
# 30       [FPS, WorldWarII, Multiplayer, Shooter, Action...           5786
# 40       [Action, FPS, Classic, Multiplayer, Shooter, F...           2387
# 50       [FPS, Action, Classic, Sci-fi, Singleplayer, S...          15489
# ...                                                    ...            ...
# 2095450  [Strategy, TowerDefense, D, Top-Down, Cartoony...            391
# 2097720  [ShootEmUp, Shooter, FemaleProtagonist, D, Act...            379
# 2103640  [Sports, Simulation, Strategy, Football, Manag...            115
# 2111630  [Simulation, Trains, Driving, Transportation, ...            272
# 2114370  [TimeManagement, Collectathon, Survival, Manag...            131
#
#          Sentiment PriceRange SentimentRange      ReviewRange  \
# AppID
# 10        0.974860    ['Mid']       [Raving]  [ReallyPopular]
# 20        0.861823  ['Cheap']         [Good]  [ReallyPopular]
# 30        0.902523  ['Cheap']       [Raving]  [ReallyPopular]
# 40        0.818182  ['Cheap']          [Mid]  [ReallyPopular]
# 50        0.951837  ['Cheap']       [Raving]  [ReallyPopular]
# ...            ...        ...            ...              ...
# 2095450   0.859335    ['Mid']         [Good]            [Mid]
# 2097720   0.831135   ['High']         [Good]            [Mid]
# 2103640   0.895652   ['High']         [Good]            [Low]
# 2111630   0.735294    ['Mid']          [Mid]            [Mid]
# 2114370   0.938931  ['Cheap']       [Raving]            [Low]
#
#                                                     Labels
# AppID
# 10       [Valve, Valve, Action, Multiplayer, PvP, Share...
# 20       [Valve, Valve, Action, Multiplayer, PvP, Share...
# 30       [Valve, Valve, Action, Multiplayer, , Raving, ...
# 40       [Valve, Valve, Action, Multiplayer, PvP, Share...
# 50       [Gearbox Software, Valve, Action, Singleplayer...
# ...                                                    ...
# 2095450  [Tiny Forge Gaming, Tiny Forge Gaming, Indie, ...
# 2097720  [上海アリス幻樂団, Mediascape Co., Ltd., Action, Indie...
# 2103640  [Axis Games, Axis Games, Indie, Simulation, Sp...
# 2111630  [ONGAKUKAN Co.,Ltd., East Japan Railway Compan...
# 2114370  [KIMIDORI SOFT, KIMIDORI SOFT, Casual, Indie, ...
#
# [15792 rows x 15 columns]

# %%
def create_mlb_df(df, columns):
    '''
    Uses MultiLabelBinarizer to transform specified columns and return a dataframe of encoded values
    
    Arguments:
        df: dataframe 
        columns: list of column names to encode
    
    Returns:
        new dataframe consisting of MultiLabelBinarizer transformed values
    '''
    #create a new empty dataframe with the same index as df
    new_df = pd.DataFrame(index=df.index)
    for column in columns:
        #instantiate a new MultiLabelBinarizer object
        mlb = MultiLabelBinarizer()
        mlb_array = mlb.fit_transform(df[column])
        mlb_df = pd.DataFrame(mlb_array, df.index, mlb.classes_)
        #concatenate each dataframe of encoded values by column
        new_df = pd.concat([new_df, mlb_df], axis=1)
    return new_df

# %%
mlb_df = create_mlb_df(steam, ['Labels'])
mlb_df
#This creates an extremely large 0/1 but at least everything is numbers for the content recommender thing
# Out:
#                  Milestone S.r.l.   101XP\t   3dm_live_wallpapers\t  \
# AppID
# 10       1  0                   0         0                       0
# 20       0  0                   0         0                       0
# 30       1  0                   0         0                       0
# 40       0  0                   0         0                       0
# 50       0  0                   0         0                       0
# ...     .. ..                 ...       ...                     ...
# 2095450  1  0                   0         0                       0
# 2097720  1  0                   0         0                       0
# 2103640  0  0                   0         0                       0
# 2111630  0  0                   0         0                       0
# 2114370  1  0                   0         0                       0
#
#           5WORD Team   AFBIK Studio  \
# AppID
# 10                 0              0
# 20                 0              0
# 30                 0              0
# 40                 0              0
# 50                 0              0
# ...              ...            ...
# 2095450            0              0
# 2097720            0              0
# 2103640            0              0
# 2111630            0              0
# 2114370            0              0
#
#           Afterburner Studios, Maple Whispering Limited   Appnori Inc.  \
# AppID
# 10                                                    0              0
# 20                                                    0              0
# 30                                                    0              0
# 40                                                    0              0
# 50                                                    0              0
# ...                                                 ...            ...
# 2095450                                               0              0
# 2097720                                               0              0
# 2103640                                               0              0
# 2111630                                               0              0
# 2114370                                               0              0
#
#           Asset Flip Studio  ...  魔物娘  鸽屋咕游戏  鸽屋谷  鹊思网络  黄昏フロンティア  黑袍  \
# AppID                        ...
# 10                        0  ...    0      0    0     0         0   0
# 20                        0  ...    0      0    0     0         0   0
# 30                        0  ...    0      0    0     0         0   0
# 40                        0  ...    0      0    0     0         0   0
# 50                        0  ...    0      0    0     0         0   0
# ...                     ...  ...  ...    ...  ...   ...       ...  ..
# 2095450                   0  ...    0      0    0     0         0   0
# 2097720                   0  ...    0      0    0     0         0   0
# 2103640                   0  ...    0      0    0     0         0   0
# 2111630                   0  ...    0      0    0     0         0   0
# 2114370                   0  ...    0      0    0     0         0   0
#
#          龍之咲, WindField Games  유진게임즈  （Hong Kong）GKD Game Studio  \
# AppID
# 10                          0      0                           0
# 20                          0      0                           0
# 30                          0      0                           0
# 40                          0      0                           0
# 50                          0      0                           0
# ...                       ...    ...                         ...
# 2095450                     0      0                           0
# 2097720                     0      0                           0
# 2103640                     0      0                           0
# 2111630                     0      0                           0
# 2114370                     0      0                           0
#
#          🚀 Raiser Games
# AppID
# 10                    0
# 20                    0
# 30                    0
# 40                    0
# 50                    0
# ...                 ...
# 2095450               0
# 2097720               0
# 2103640               0
# 2111630               0
# 2114370               0
#
# [15792 rows x 12733 columns]

# %%
SteamGameList = list(steam.Name.values)

# %%
RecommendationList =
